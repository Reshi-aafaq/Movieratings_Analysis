# %%
import pandas as pd

# %%
df=pd.read_csv("C:/Users/hp/Desktop/Datasets/movies.csv")

# %%
df.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
df.columns=[x.lower() for x in df.columns]
filt=(df["audience ratings %"]) > 95
df.loc[filt,["film","audience ratings %"]].apply(lambda x:x.max())
# Out:
# film                  The Dark Knight
# audience ratings %                 96
# dtype: object

# %%
df.apply(lambda x: x.max())
# Out:
# film                         Zookeeper
# genre                         Thriller
# rotten tomatoes ratings %           97
# audience ratings %                  96
# budget (million $)                 300
# year of release                   2011
# dtype: object

# %%
def maxx(email):
    return email.max()

# %%
abc=df.apply(maxx)

# %%
filtt=(lambda x:x.max())

# %%
xx=df.loc[filtt]
xx.fillna(value=0)
# Out:
# D:\anacondaaa\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
#   """Entry point for launching an IPython kernel.
#                                   film   genre  rotten tomatoes ratings %  \
# Zookeeper                            0       0                        0.0
# Thriller                             0       0                        0.0
# 97         Don't Be Afraid Of The Dark  Horror                       59.0
# 96                        Dolphin Tale   Drama                       84.0
# 300                  Pineapple Express  Action                       68.0
# 2011                                 0       0                        0.0
#
# ...

# %%
abc
# Out:
# film                         Zookeeper
# genre                         Thriller
# rotten tomatoes ratings %           97
# audience ratings %                  96
# budget (million $)                 300
# year of release                   2011
# dtype: object

# %%
filtr=(df["budget (million $)"]==300) | (df["audience ratings %"]==96) | (df["rotten tomatoes ratings %"]==97)
final=df.loc[filtr,["rotten tomatoes ratings %","audience ratings %","film"]]
final
# Out:
#      rotten tomatoes ratings %  audience ratings %  \
# 304                         45                  74
# 387                         97                  91
# 406                         94                  96
# 431                         97                  83
# 455                         97                  87
#
#                                          film
# 304  Pirates of the Caribbean: At World's End
# 387                                The Artist
# 406                           The Dark Knight
# 431                          The Hurt Locker
# 455                               The Muppets

# %%
final.describe()
# Out:
#        rotten tomatoes ratings %  audience ratings %
# count                   5.000000            5.000000
# mean                   86.000000           86.200000
# std                    22.956481            8.348653
# min                    45.000000           74.000000
# 25%                    94.000000           83.000000
# 50%                    97.000000           87.000000
# 75%                    97.000000           91.000000
# max                    97.000000           96.000000

# %%
cofnl=final.corr()
cofnl
# Out:
#                            rotten tomatoes ratings %  audience ratings %
# rotten tomatoes ratings %                   1.000000            0.789176
# audience ratings %                          0.789176            1.000000

# %%
df.iloc[406]
# Out:
# film                         The Dark Knight
# genre                               Thriller
# rotten tomatoes ratings %                 94
# audience ratings %                        96
# budget (million $)                       185
# year of release                         2008
# Name: 406, dtype: object

# %%
df[df["film"]=="The Dark Knight"]
# Out:
#                 film     genre  rotten tomatoes ratings %  audience ratings %  \
# 406  The Dark Knight  Thriller                         94                  96
#
#      budget (million $)  year of release
# 406                 185             2008

# %%
df.head(20)
# Out:
#                                  film      genre  rotten tomatoes ratings %  \
# 0               (500) Days of Summer      Comedy                         87
# 1                         10,000 B.C.  Adventure                          9
# 2                          12 Rounds      Action                         30
# 3                           127 Hours  Adventure                         93
# 4                           17 Again      Comedy                         55
# 5                                2012     Action                         39
# 6                          27 Dresses     Comedy                         40
# 7                    30 Days of Night     Horror                         50
# 8                  30 Minutes or Less     Comedy                         43
# 9                               50/50     Comedy                         93
# 10                         88 Minutes      Drama                          5
# ...

# %% [markdown]
# According to my analysis,The dark Knight movie is most intresting to watch.

# %%
rr=df.groupby(["genre"])

# %%
rr.get_group("Action")
# Out:
#                           film   genre  rotten tomatoes ratings %  \
# 2                   12 Rounds   Action                         30
# 5                         2012  Action                         39
# 15                   Abduction  Action                          4
# 29                   Appaloosa  Action                         77
# 30                    Armored   Action                         40
# ..                         ...     ...                        ...
# 531                  Watchmen   Action                         64
# 542                  Whiteout   Action                          7
# 546  X-Men Origins: Wolverine   Action                         37
# 547         X-Men: First Class  Action                         87
# 557                Zombieland   Action                         90
#
#      audience ratings %  budget (million $)  year of release
# 2                    52                  20             2009
# ...

# %%
df.fillna(0)
# Out:
#                       film      genre  rotten tomatoes ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      audience ratings %  budget (million $)  year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...
